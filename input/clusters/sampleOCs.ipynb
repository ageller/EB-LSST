# %%
import pandas as pd

# %%
OC = pd.read_csv('OCdataForEBLSST.csv')
OC
# Out:
#                        ID        RA[hr]       Dec[deg]     dist[pc]  \
# 0     [KPS2012]_MWSC_4688  23 51 54.000  -86 43 12.000  1336.000000
# 1     [KPS2012]_MWSC_5684  12 53 43.000  -86 38 54.000  1432.000000
# 2     [KPS2012]_MWSC_5692  17 47 20.000  -86 36 36.000  1555.000000
# 3     [KPS2012]_MWSC_4005  00 11 28.000  -85 28 48.000  1159.000000
# 4     [KPS2012]_MWSC_4176  14 27 18.000  -85 25 12.000  1093.000000
# 5                 ESO_8-6  14 56 55.000  -83 26 42.000  1380.000000
# 6     [KPS2012]_MWSC_4219  15 42 14.000  -83 11 42.000  1606.000000
# 7     [KPS2012]_MWSC_5575  01 59 42.000  -83 03 00.000  2191.000000
# 8     [KPS2012]_MWSC_4682  23 43 23.000  -82 57 36.000  1065.000000
# 9     [KPS2012]_MWSC_5685  13 05 24.000  -82 02 36.000  1581.000000
# 10    [KPS2012]_MWSC_5681  10 41 47.000  -82 00 18.000  1700.000000
# 11    [KPS2012]_MWSC_2014  12 20 06.000  -81 30 36.000  2671.000000
# 12    [KPS2012]_MWSC_2064  12 45 43.000  -81 15 30.000  1456.000000
# ...

# %%
sample = OC.loc[(OC['dist[pc]'] < 2000) & (OC['mass[Msun]'] > 200) & (OC['age[Myr]'] > 1000)]
sample.to_csv('OCsForEmily.csv', index=False)
print(len(sample))
# Out:
# 19

# %%
sample = OC.loc[(OC['dist[pc]'] < 3000) & (OC['mass[Msun]'] > 200) & (OC['age[Myr]'] > 1000)]
sample.to_csv('OCsForEmily_3kpc.csv', index=False)
print(len(sample))
# Out:
#                           ID        RA[hr]       Dec[deg]     dist[pc]  \
# 65              [KPR2005]_78  15 05 37.000  -68 24 18.000  2820.500000
# 66          Cl_Collinder_261  12 38 04.560  -68 22 37.200  2529.940000
# 80              [KPR2005]_57  10 10 55.000  -66 42 00.000  1491.500000
# 154                Cl_Dias_4  13 43 25.000  -63 00 00.000  2153.333333
# 538                 NGC_6253  16 59 06.720  -52 42 43.200  1546.340000
# 612                  IC_4651  17 24 50.880  -49 55 01.200   867.328571
# 842               C_0829-385  08 31 20.160  -38 38 24.000  1588.020000
# 864               C_0850-374  08 52 03.000  -37 36 36.000  2630.500000
# 1327                NGC_6507  17 59 48.000  -17 25 06.000  2881.333333
# 1351              C_1829-160  18 32 02.880  -16 03 43.200  1249.600000
# 1653                NGC_2112  05 53 48.480   00 24 10.800   951.520000
# 1682              C_0635+020  06 38 42.480   02 04 08.400  2165.660000
# ...

# %%
sample = OC.loc[(OC['dist[pc]'] < 5000) & (OC['dist[pc]'] >= 3000) & (OC['mass[Msun]'] > 200) & (OC['age[Myr]'] > 1000)]
sample.to_csv('OCsForEmily_3to5kpc.csv', index=False)
#print(len(sample))
sample
# Out:
#                   ID        RA[hr]       Dec[deg]     dist[pc]   rhm[pc]  \
# 270   Cl_Trumpler_20  12 39 31.680  -60 38 13.200  3152.500000  5.517125
# 1015        NGC_2243  06 29 34.800  -31 16 55.200  4259.300000  2.646406
# 1328        NGC_6647  18 31 28.000  -17 20 24.000  4230.666667  9.853463
# 1379        NGC_2425  07 38 18.480  -14 53 06.000  3922.700000  2.268110
# 1462        NGC_2506  08 00 02.400  -10 46 22.800  3328.071429  5.031000
# 1715       Cl_Dias_2  06 09 09.840   04 34 22.800  3242.150000  2.675595
# 1753  Cl_Berkeley_32  06 58 07.200   06 25 58.800  4738.200000  3.161761
# 1805        NGC_2141  06 02 56.160   10 27 03.600  4300.575000  5.296886
# 2007        NGC_2158  06 07 26.880   24 05 56.400  4852.850000  3.797136
# 2206   Cl_Czernik_21  05 26 41.040   36 00 46.800  3900.575000  2.853347
# 2242        NGC_6791  19 20 53.040   37 46 40.800  4922.633333  6.139478
# 2351        NGC_7044  21 13 08.160   42 29 38.400  3195.920000  2.699200
# ...

# %%
sample = OC.loc[(OC['mass[Msun]'] > 200) & (OC['age[Myr]'] > 2500) & (OC['dist[pc]'] >= 5000)]
#sample.to_csv('OCsForEmily_2_5Gyr.csv', index=False)
sample
# Out:
#             ID        RA[hr]       Dec[deg]  dist[pc]    rhm[pc]  mass[Msun]  \
# 3039  NGC_4372  12 25 45.480  -72 39 32.400    5807.0  13.506994       203.0
# 3047  NGC_5139  13 26 47.400  -47 28 48.000    5199.0  16.809934       858.5
# 3153  NGC_6539  18 04 49.800  -07 35 09.600    7801.0   5.424940       230.0
# 3162   IC_1276  18 10 44.040  -07 12 28.800    5399.0  10.407028       441.0
#
#           age[Myr]  [Fe/H]  sigma_v0_z[km/s]  OpSimID  OpSimRA[deg]  \
# 3039  12589.254118  -1.945          0.111445    133.0    189.188776
# 3047  12589.254118  -1.445          0.205437    699.0    200.659316
# 3153   8912.509381  -0.630          0.187180   2241.0    271.055174
# 3162  12589.254118  -0.650          0.187132   2355.0    272.525243
#
#       OpSimDec[deg]
# 3039     -72.099671
# 3047     -47.424471
# 3153      -8.950029
# 3162      -6.538104
